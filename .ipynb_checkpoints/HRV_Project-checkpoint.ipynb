# %% [markdown]
# # Heart Rate Variability Distribution

# %% [markdown]
# Heart rate variability (HRV) represents one of the most promising markers to determine impact of various lifestyle factors, biological factors, and fitness factors on our physical health. Many commercial devices e.g fitness watches, mobile phone apps now provide automated measurement of HRV,  providing various disciplines with a seemingly simple tool for both research and clinical studies.
#
# Variations in heart rate may be evaluated by a number of methods. Perhaps the simplest to perform are the time
# domain measures. With these methods either the heart rate at any point in time or the intervals between
# successive normal complexes are determined. In a continuous electrocardiographic (ECG) record, each QRS
# complex is detected, and the so-called normal-to-normal (NN) intervals (that is all intervals between adjacent
# QRS complexes resulting from sinus node depolarizations), or the instantaneous heart rate is determined.
# Simple time–domain variables that can be calculated include the mean NN interval, the mean heart rate, the difference between the longest and shortest NN interval, the difference between night and day heart rate, etc.
#
# **add image**

# %%
#import libraries

import os
import glob
import numpy as np
import random
import pandas as pd
import neurokit2 as nk # provides data on NN interval distributions
import matplotlib.pyplot as plt # used to create distribution plots
import seaborn as sns  # used to visualize random distributions

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_1\user_info.csv', encoding='utf8')
data.head()

user1 = data [['Gender', 'Weight', 'Age']]

user1.head()
# Out:
#   Gender  Weight  Age
# 0      M      65   29

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_1\RR.csv', encoding='utf8')

user1_HRV = data.mean () [['ibi_s']]
user1_HRV.head ()
# Out:
# ibi_s    0.712331
# dtype: float64

# %%
auser1 = pd.concat([user1, user1_HRV], ignore_index=True)
auser1
# Out:
#           0   Age Gender  Weight
# 0       NaN  29.0      M    65.0
# 1  0.712331   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_2\user_info.csv', encoding='utf8')
user2 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_2\RR.csv', encoding='utf8')
user2_HRV = data.mean () [['ibi_s']]

auser2 = pd.concat([user2, user2_HRV], ignore_index=True)
auser2
# Out:
#          0   Age Gender  Weight
# 0      NaN  27.0      M    95.0
# 1  0.82756   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_3\user_info.csv', encoding='utf8')
user3 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_3\RR.csv', encoding='utf8')
user3_HRV = data.mean () [['ibi_s']]

auser3 = pd.concat([user3, user3_HRV], ignore_index=True)
auser3
# Out:
#           0   Age Gender  Weight
# 0       NaN  34.0      M    70.0
# 1  0.777856   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_4\user_info.csv', encoding='utf8')
user4 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_4\RR.csv', encoding='utf8')
user4_HRV = data.mean () [['ibi_s']]

auser4 = pd.concat([user4, user4_HRV], ignore_index=True)
auser4
# Out:
#           0   Age Gender  Weight
# 0       NaN  27.0      M    76.0
# 1  0.995826   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_5\user_info.csv', encoding='utf8')
user5 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_5\RR.csv', encoding='utf8')
user5_HRV = data.mean () [['ibi_s']]

auser5 = pd.concat([user5, user5_HRV], ignore_index=True)
auser5
# Out:
#           0   Age Gender  Weight
# 0       NaN  25.0      M    80.0
# 1  0.807307   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_6\user_info.csv', encoding='utf8')
user6 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_6\RR.csv', encoding='utf8')
user6_HRV = data.mean () [['ibi_s']]

auser6 = pd.concat([user6, user6_HRV], ignore_index=True)
auser6
# Out:
#           0   Age Gender  Weight
# 0       NaN  27.0      M    62.0
# 1  0.704021   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_7\user_info.csv', encoding='utf8')
user7 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_7\RR.csv', encoding='utf8')
user7_HRV = data.mean () [['ibi_s']]

auser7 = pd.concat([user7, user7_HRV], ignore_index=True)
auser7
# Out:
#           0   Age Gender  Weight
# 0       NaN  25.0      M    65.0
# 1  0.792519   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_8\user_info.csv', encoding='utf8')
user8 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_8\RR.csv', encoding='utf8')
user8_HRV = data.mean () [['ibi_s']]

auser8 = pd.concat([user8, user8_HRV], ignore_index=True)
auser8
# Out:
#           0   Age Gender  Weight
# 0       NaN  40.0      M    74.0
# 1  0.831834   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_9\user_info.csv', encoding='utf8')
user9 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_9\RR.csv', encoding='utf8')
user9_HRV = data.mean () [['ibi_s']]

auser9 = pd.concat([user9, user9_HRV], ignore_index=True)
auser9
# Out:
#          0   Age Gender  Weight
# 0      NaN  20.0      M    70.0
# 1  0.82171   NaN    NaN     NaN

# %%
data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_10\user_info.csv', encoding='utf8')
user10 = data [['Gender', 'Weight', 'Age']]

data = pd.read_csv(r'C:\Users\suseh\OneDrive\Desktop\HRV_Project\Data\user_10\RR.csv', encoding='utf8')
user10_HRV = data.mean () [['ibi_s']]

auser10 = pd.concat([user10, user10_HRV], ignore_index=True)
auser10
# Out:
#           0   Age Gender  Weight
# 0       NaN  27.0      M    85.0
# 1  0.829057   NaN    NaN     NaN

# %%
allusers = pd.concat ([auser1, auser2, auser3, auser4, auser6, auser7, auser8, auser9, auser10 ], ignore_index=False)
allusers
# Out:
#           0   Age Gender  Weight
# 0       NaN  29.0      M    65.0
# 1  0.712331   NaN    NaN     NaN
# 0       NaN  27.0      M    95.0
# 1  0.827560   NaN    NaN     NaN
# 0       NaN  34.0      M    70.0
# 1  0.777856   NaN    NaN     NaN
# 0       NaN  27.0      M    76.0
# 1  0.995826   NaN    NaN     NaN
# 0       NaN  27.0      M    62.0
# 1  0.704021   NaN    NaN     NaN
# 0       NaN  25.0      M    65.0
# 1  0.792519   NaN    NaN     NaN
# 0       NaN  40.0      M    74.0
# 1  0.831834   NaN    NaN     NaN
# 0       NaN  20.0      M    70.0
# 1  0.821710   NaN    NaN     NaN
# 0       NaN  27.0      M    85.0
# 1  0.829057   NaN    NaN     NaN

# %%
#distirbution graph

# %%
# graph

# %%
#using nuerokit2 example of plot distribution
hrv_time = nk.hrv_time(peaks, sampling_rate=100, show=True)
hrv_time
# Out:
#     HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1060.020964  83.466138   36.602126   76.783897   17.685523   81.692637
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  HRV_CVNN  HRV_CVSD  \
# 0         NaN         NaN  64.451467  64.519189   0.07874  0.060802
#
#    HRV_MedianNN  HRV_MadNN  HRV_MCVNN  HRV_IQRNN  HRV_pNN50  HRV_pNN20  \
# 0        1070.0     88.956   0.083136      110.0  40.880503  68.553459
#
#      HRV_HTI  HRV_TINN
# 0  16.448276   328.125

# %%
#Distribution of HRV_NN using np.random
#seed with the mean 1060.020964
#standard deviation 83.466138
mu, sigma = 1060.020964, 83.466138 # mean and standard deviation

s = np.random.default_rng().normal(mu, sigma, 1000) #1000 sample
sns.displot (s, kde=True)
plt.ylabel('Sample number')
plt.xlabel('HRV_NN Score')
plt.title ("Histogram data of HRV_NN scores.")
plt.show()

# %%
#Nuerokit2 example

# Download data
data = nk.data("bio_resting_8min_100hz")

# Find peaks
peaks, info = nk.ecg_peaks(data["ECG"], sampling_rate=100)

# Compute HRV indices
nk.hrv(peaks, sampling_rate=100, show=True)
# Out:
#     HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  1060.020964  83.466138   36.602126   76.783897   17.685523   81.692637
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_SampEn  HRV_ShanEn  \
# 0         NaN         NaN  64.451467  64.519189  ...    1.689328    4.989563
#
#    HRV_FuzzyEn   HRV_MSE  HRV_CMSE  HRV_RCMSE   HRV_CD   HRV_HFD  HRV_KFD  \
# 0     1.255956  1.383481  1.427822   2.030929  1.51032  1.923361  3.50486
#
#     HRV_LZC
# 0  0.876727
#
# [1 rows x 77 columns]

# %% [markdown]
# ### References
#
# Makowski, D., Pham, T., Lau, Z. J., Brammer, J. C., Lespinasse, F., Pham, H.,
# Schölzel, C., & Chen, S. A. (2021). NeuroKit2: A Python toolbox for neurophysiological signal processing.
# Behavior Research Methods. https://doi.org/10.3758/s13428-020-01516-y
#
# https://neurokit2.readthedocs.io/en/latest/introduction.html
#
# https://www.escardio.org/static-file/Escardio/Guidelines/Scientific-Statements/guidelines-Heart-Rate-Variability-FT-1996.pdf
